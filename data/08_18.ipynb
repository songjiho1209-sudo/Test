# %%
import pandas as pd

df = pd.read_csv('15_01_secom_교육샘플.csv')
print(df)
# Out:
#                     측정시각  불량여부   센서01   센서02   센서03   센서04     센서05  센서06  \
# 0    19/07/2008 11:55:00     0  1.500  0.016 -0.003  0.946  202.440   0.0
# 1    19/07/2008 12:32:00     0  1.497 -0.000 -0.015  0.963  200.547   0.0
# 2    19/07/2008 13:17:00     1  1.444  0.004  0.001  0.962  202.018   0.0
# 3    19/07/2008 14:43:00     0  1.488 -0.012 -0.003  0.963  201.848   0.0
# 4    19/07/2008 15:22:00     0  1.503 -0.003 -0.007  0.957  201.942   0.0
# ..                   ...   ...    ...    ...    ...    ...      ...   ...
# 245  18/08/2008 04:12:00     0  1.419 -0.030  0.007  0.955  199.036   0.0
# 246  18/08/2008 04:35:00     0  1.424 -0.006 -0.009  0.957  202.649   0.0
# 247  18/08/2008 05:03:00     0  1.492 -0.007 -0.004  0.952  198.732   0.0
# 248  18/08/2008 05:25:00     0  1.449  0.018 -0.002  0.944  200.256   0.0
# 249  18/08/2008 06:07:00     0  1.481 -0.011 -0.005  0.959  200.517   0.0
#
#        센서07     센서08  ...  센서11   센서12  센서13   센서14    센서15   센서16     센서17  \
# ...

# %%
import numpy as np

a = np.nan

print(a)

print(a == a)

print(a != a)
# Out:
# nan
# False
# True

# %%
df2 = pd.read_csv('15_02_설비센서_샘플.csv')
print(df2)

print(df.isna())
# Out:
#                 측정시각   설비명     온도   압력     진동  가동시간  불량여부
# 0   2024-03-01 09:00  프레스1   72.4  5.2    3.1   120     0
# 1   2024-03-01 10:00  프레스1   73.1  5.3    3.0   121     0
# 2   2024-03-01 11:00  프레스1    NaN  5.1    2.9   122     0
# 3   2024-03-01 12:00  프레스1   74.0  0.0    3.2   123     1
# 4   2024-03-01 13:00  프레스2   68.9  4.8 -999.0    80     0
# 5   2024-03-01 14:00  프레스2   69.5  4.9    2.5    81     0
# 6   2024-03-01 15:00  프레스2   70.2  NaN    2.6    82     0
# 7   2024-03-01 16:00   NaN   71.0  5.0    2.7    83     0
# 8   2024-03-01 17:00  프레스2  999.0  5.1    2.8    84     1
# 9   2024-03-02 09:00  절삭기A   65.3  6.1    4.0   200     0
# 10  2024-03-02 10:00  절삭기A   66.0  6.2 -999.0   201     0
# 11  2024-03-02 11:00  절삭기A   66.8  0.0    4.2   202     1
# 12  2024-03-02 12:00  절삭기A    NaN  6.0    4.1   203     0
# 13  2024-03-02 13:00  절삭기B   64.1  5.9    3.8   150     0
# 14  2024-03-02 14:00  절삭기B   64.8  6.0    3.9   151     0
# ...
