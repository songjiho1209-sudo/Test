# %%
# narray: 배열 (우리가 학습했던 리스트와 다른 자료형)
# numpy에서 자료를 담는 그릇
# 같은 자료형만 담음 (ex. 정수 배열, 실수 배열)
# 정해진 형태를 가지고 잇음 (한 줄로 구성되어 있거나 표 모양)

# 리스트로 배열의 요소들에 *5릃 하는 코드 작성


type_list= [1, 2, 3, 4, 5]
times_5 = []
for num in type_list:
    times = num*5
    times_5.append(tiems)

print(tiems_5)
